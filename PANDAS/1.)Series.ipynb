# %%
import numpy as np
import pandas as pd

# %%
labels = ['a','b','c']

arr = np.array([1,2,3])
my_list = [1,2,3]
dct = {'e':10,'f':20,'g':30}

# %%
print(pd.Series(arr,index=labels))
# Out:
# a    1
# b    2
# c    3
# dtype: int64

# %%
pd.Series(my_list,index = labels)
# Out:
# a    1
# b    2
# c    3
# dtype: int64

# %%
pd.Series(dct)
# Out:
# e    10
# f    20
# g    30
# dtype: int64
