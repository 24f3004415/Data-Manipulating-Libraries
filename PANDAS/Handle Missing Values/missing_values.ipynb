# %%
import numpy as np
import pandas as pd

# %%
df = pd.read_csv("raw_data.csv")

# %%
# isnull() / isna() → Detect missing values (returns True where data is missing)
df.isna()

# isnull().sum() → Counts total missing values in each column
df.isnull().sum()

# dropna() → Removes rows (or columns) that contain missing values
df.dropna()  #Drow Row
df.dropna(axis=1)  #Drop Columns

# fillna(value) → Replaces missing values with a specified value
df.fillna(0)

cleaned_age_data = df.copy()
age_mean = cleaned_age_data['age'].mean()
print(f"the mean of the age column is:- {age_mean}")
cleaned_age_data['age'] = cleaned_age_data['age'].fillna(age_mean)
cleaned_age_data

# ffill() → Forward fill (fills missing values using previous valid value)
df.ffill()

# bfill() → Backward fill (fills missing values using next valid value)
df.bfill()
# Out:
# the mean of the age column is:- 32.75
#     id          name    age country   gender   income
# 0    1      John Doe  29.00     USA     Male  55000.0
# 1    1      John Doe  29.00     USA     Male  55000.0
# 2    2    Jane Smith  32.75  Canada   Female  62000.0
# 3    3          Alex  32.75     USA  Unknown  47000.0
# 4    4  Maria Garcia  34.00   Spain   Female      NaN
# 5    5        Li Wei  27.00   China     Male  51000.0
# 6    6           NaN  45.00   India   Female  73000.0
# 7    7    Ahmed Khan  38.00     NaN     Male  68000.0
# 8    8    Rachel Lee  29.00     USA   Female  62000.0
# 9    9   Carlos Ruiz  32.75  Mexico     Male  45000.0
# 10  10   Emily Davis  31.00     USA      NaN  58000.0
